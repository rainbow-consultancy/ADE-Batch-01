# %%
dbutils.widgets.text("MyTextWidget", "")

# %%
var  = dbutils.widgets.get("MyTextWidget")
print(var)

# %%
dbutils.widgets.dropdown("MyDropdownWidget", "1", ["1", "2", "3"])
var2  = dbutils.widgets.get("MyDropdownWidget")
print(var2)

# %%
dbutils.widgets.multiselect("MyMultiWidget", "1", ["1", "2", "3", "4"])
var3  = dbutils.widgets.get("MyMultiWidget")
print(var3)

# %%
type(v3)

# %%
var3.split(",")

# %%
v1, v2, v3 = var3.split(",")[0], var3.split(",")[1], var3.split(",")[2]
print(v1, v2, v3)

# %%
dbutils.widgets.combobox("MyComboWidget", "1", ["1", "2", "3", "4"])
var4  = int(dbutils.widgets.get("MyComboWidget"))
print(var4)

type(var4)
