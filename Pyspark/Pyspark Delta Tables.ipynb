# %%
from pyspark.sql import functions as F

# %%
loans_df = spark.read.format("parquet").load("/Volumes/workspace/default/kaggle_datasets/Loans")
loans_df.display()

# %%
loans_df.groupBy("ACTIONTYPE").agg(F.count("ACTIONTYPE")).display()

# %%
loans_df.count()

# %%
loans_df.write.format("delta").mode("overwrite").save("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")

# %%
# loans_df_filtered = loans_df.filter(F.col("ACTIONTYPE") != "A")
loans_df_filtered = loans_df.filter((F.col("ACTIONTYPE") == "A"))
loans_df_filtered.count()

# %%
loans_df_filtered.write.format("delta").mode("overwrite").save("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")

# %%
df = spark.read.format("delta").load("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")
df.count()

# %%
df = spark.read.format("delta").option("versionAsOf", 0).load("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")
df.count()

# %%
df.display()

# %%
from delta.tables import DeltaTable
deltaTable = DeltaTable.forPath(spark, "/Volumes/workspace/default/kaggle_datasets/DeltaLoans")

deltaTable.history().display()

# %%
# loans_df_filtered = loans_df.filter(F.col("ACTIONTYPE") != "A")
loans_df_filtered = loans_df.withColumn("is_active", F.lit(True))
loans_df_filtered.count()

# %%
loans_df_filtered.write.format("delta").mode("overwrite").option("mergeSchema", "true").save("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")

# %%
loans_df = spark.read.format("delta").load("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")
loans_df.display()

# %%
loans_df = spark.read.format("delta").option("versionAsOf", 0).load("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")
loans_df.display()

# %%
# %sql
RESTORE TABLE delta.`/Volumes/workspace/default/kaggle_datasets/DeltaLoans` TO VERSION AS OF 0

# %%
loans_df = spark.read.format("delta").load("/Volumes/workspace/default/kaggle_datasets/DeltaLoans")
loans_df.display()

# %%
loans_df.count()

# %%
file_path = "/Volumes/workspace/default/kaggle_datasets/employee_salary_dataset.csv"
emp_df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load(file_path)
emp_df.display()

# %%
emp_df.write.format("delta").mode("overwrite").saveAsTable("workspace.default.employee_salary")

# %%
# %sql
select * from workspace.default.employee_salary limit 10;

# %%
# %sql

update workspace.default.employee_salary
set Department = 'Information Technology'
where Department = 'IT';

# %%
# %sql

desc history workspace.default.employee_salary;

# %%
# %sql

alter table workspace.default.employee_salary
add column is_active boolean;

# %%
# %sql

update workspace.default.employee_salary
set is_active = true;

# %%
# %sql
desc history workspace.default.employee_salary;

# %%
# %sql
select * from workspace.default.employee_salary
version as of 0;

# %%
# %sql
restore workspace.default.employee_salary version as of 0;

# %%
# %sql
select * from workspace.default.employee_salary;

# %%
# %sql
OPTIMIZE workspace.default.employee_salary;

# %%
# %sql
desc history workspace.default.employee_salary;

# %%
# %sql
vacuum workspace.default.employee_salary retain 0 hours;

# %%
spark.conf.get("spark.databricks.delta.retentionDurationCheck.enabled", "false")
